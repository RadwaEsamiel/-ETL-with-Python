# %%
import sqlalchemy as db
import pandas as pd
import numpy as np


path = "/home/radwa/Radwa.Usecase/staging_1/Exchange/exchange.csv"

df_rateexchange = pd.read_csv(path)

# %%
path = "/home/radwa/Radwa.Usecase/staging_1/order_item/order_item.csv"

df_order_items = pd.read_csv(path)

# %%
df_rateexchange
# Out:
#   currency  exchange_rate            timestamp                Extract_time  \
# 0      EGP        47.8519  2024-05-01 18:00:00  2024-05-02 11:57:33.663846
#
#   Source
# 0    API

# %%
df_merged_items_exchange = pd.merge(
    df_order_items,
    df_rateexchange[['exchange_rate']],  
    how='cross' 
)

# %%
df_merged_items_exchange['list_price_egp'] = df_merged_items_exchange['list_price'] * df_merged_items_exchange['exchange_rate']

# %%
df_merged_items_exchange
# Out:
#       order_id  item_id  product_id  quantity  list_price  discount  \
# 0            1        1          20         1      599.99      0.20
# 1            1        2           8         2     1799.99      0.07
# 2            1        3          10         2     1549.00      0.05
# 3            1        4          16         2      599.99      0.05
# 4            1        5           4         1     2899.99      0.20
# ...        ...      ...         ...       ...         ...       ...
# 4600      1615        9         182         1     2499.99      0.20
# 4601      1612        0         289         2      319.99      0.05
# 4602      1612        0         101         2      339.99      0.20
# 4603      1612        0         293         2      319.99      0.07
# 4604      1612        0          60         1     1559.99      0.10
#
#                     Extract_time    Source  exchange_rate  list_price_egp
# 0     2024-05-02 11:55:01.355526  postgres        47.8519    28710.661481
# ...

# %%
import os

csv_path = "/home/radwa/Radwa.Usecase/staging_2/Exchange/exchange.csv" 

directory = os.path.dirname(csv_path)
if not os.path.exists(directory):
    os.makedirs(directory)
    
df_rateexchange.to_csv(csv_path, index=False)

# %%
csv_path = "/home/radwa/Radwa.Usecase/staging_2/order_items/order_items.csv" 

directory = os.path.dirname(csv_path)
if not os.path.exists(directory):
    os.makedirs(directory)
    
df_merged_items_exchange.to_csv(csv_path, index=False)
