# %%
import sqlalchemy as db
import pandas as pd
import numpy as np


path = "/home/radwa/Radwa.Usecase/staging_1/Customers/customers.csv"

df_customers = pd.read_csv(path)

# %%
path = "/home/radwa/Radwa.Usecase/staging_1/Stores/stores.csv"

df_stores = pd.read_csv(path)

# %%
store_cities = df_stores['city'].unique()

# %%
store_cities = df_stores['city'].unique()
df_customers['local'] = df_customers['city'].isin(store_cities)

# %%
df_customers
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks         unknown
# 1               2       Kasha      Todd         unknown
# 2               3      Tameka    Fisher         unknown
# 3               4       Daryl    Spence         unknown
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison         unknown
# 1441         1442      Cassie     Cline         unknown
# 1442         1443      Lezlie      Lamb         unknown
# 1443         1444      Ivette     Estes         unknown
# 1444         1445       Ester   Acevedo         unknown
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
import os

csv_path = "/home/radwa/Radwa.Usecase/staging_2/Customers/customers.csv" 

directory = os.path.dirname(csv_path)
if not os.path.exists(directory):
    os.makedirs(directory)
    
df_customers.to_csv(csv_path, index=False)

# %%
import os

csv_path = "/home/radwa/Radwa.Usecase/staging_2/Stores/stores.csv" 

directory = os.path.dirname(csv_path)
if not os.path.exists(directory):
    os.makedirs(directory)
    
df_stores.to_csv(csv_path, index=False)
