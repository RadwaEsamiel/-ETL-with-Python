# %%
import sqlalchemy as db
import pandas as pd
import numpy as np


path = "/home/radwa/Radwa.Usecase/Landing/Customers/customers.csv"

df_customers = pd.read_csv(path)

# %%
df_customers.isnull().sum()
# Out:
# customer_id        0
# first_name         0
# last_name          0
# phone           1267
# email              0
# street             0
# city               0
# state              0
# zip_code           0
# Extract_time       0
# Source             0
# dtype: int64

# %%
df_customers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1445 entries, 0 to 1444
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   customer_id   1445 non-null   int64
#  1   first_name    1445 non-null   object
#  2   last_name     1445 non-null   object
#  3   phone         178 non-null    object
#  4   email         1445 non-null   object
#  5   street        1445 non-null   object
#  6   city          1445 non-null   object
#  7   state         1445 non-null   object
#  8   zip_code      1445 non-null   int64
#  9   Extract_time  1445 non-null   object
#  10  Source        1445 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 124.3+ KB

# %%
df_customers_phones = "unknown"

df_customers['phone'].fillna(df_customers_phones, inplace=True)

# %%
df_customers.shape
# Out:
# (1445, 11)

# %%
df_customers_final = df_customers.drop_duplicates()

# %%
df_customers_final
# Out:
#       customer_id  first_name last_name           phone  \
# 0               1       Debra     Burks         unknown
# 1               2       Kasha      Todd         unknown
# 2               3      Tameka    Fisher         unknown
# 3               4       Daryl    Spence         unknown
# 4               5  Charolette      Rice  (916) 381-6003
# ...           ...         ...       ...             ...
# 1440         1441      Jamaal  Morrison         unknown
# 1441         1442      Cassie     Cline         unknown
# 1442         1443      Lezlie      Lamb         unknown
# 1443         1444      Ivette     Estes         unknown
# 1444         1445       Ester   Acevedo         unknown
#
#                         email                  street           city state  \
# 0       debra.burks@yahoo.com       9273 Thorne Ave.    Orchard Park    NY
# 1        kasha.todd@yahoo.com        910 Vine Street        Campbell    CA
# ...

# %%
import os

csv_path = "/home/radwa/Radwa.Usecase/staging_1/Customers/customers.csv" 

directory = os.path.dirname(csv_path)
if not os.path.exists(directory):
    os.makedirs(directory)
    
df_customers_final.to_csv(csv_path, index=False)
